# %% [markdown]
# <a href="https://colab.research.google.com/github/robertbarac/EDA-Brazilian-ecommerce/blob/main/eda_brazilian_ecommerce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install --upgrade pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd '/content/drive/My Drive/Colab Notebooks/brazilian-e-commerce/CSVs'
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/brazilian-e-commerce/CSVs
# olist_customers_dataset.csv	  olist_orders_dataset.csv
# olist_geolocation_dataset.csv	  olist_products_dataset.csv
# olist_order_items_dataset.csv	  olist_sellers_dataset.csv
# olist_order_payments_dataset.csv  product_category_name_translation.csv
# olist_order_reviews_dataset.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.__version__
# Out:
# '1.3.5'

# %%
df_customers = pd.read_csv('olist_customers_dataset.csv')
df_customers#['customer_state'].value_counts(dropna=False)
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
df_orders = pd.read_csv('olist_orders_dataset.csv')
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_geolocation = pd.read_csv('olist_geolocation_dataset.csv')
#df_geolocation['geolocation_state'].value_counts()
df_geolocation
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
df_products = pd.read_csv('olist_products_dataset.csv')
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df_order_items = pd.read_csv('olist_order_items_dataset.csv')
df_order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_sellers = pd.read_csv('olist_sellers_dataset.csv')
df_sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
df_order_payments = pd.read_csv('olist_order_payments_dataset.csv')
df_order_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
df_product_category_name = pd.read_csv('product_category_name_translation.csv')
df_product_category_name
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
df_order_reviews = pd.read_csv('olist_order_reviews_dataset.csv')
df_order_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# #¿Qué categorías de productos tiene buena calificación y cuáles tienen malas calificaciones?

# %%
df_good_score = df_order_reviews[df_order_reviews['review_score'] > 3]
df_good_score
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title  \
# ...

# %%
df_regular_score = df_order_reviews[df_order_reviews['review_score'] == 3]
df_regular_score
# Out:
#                               review_id                          order_id  \
# 14     9a0abbb668bafb95a6d2b05db43284c4  d7bd0e4afdf94846eb73642b4e3e75c3
# 18     fdbdb2629a7cde0f66657acc92084e7f  70a752414a13d09cc1f2b437b914b28e
# 56     cb6fe4f91f83d9222b7c8e14959055e1  84226f5c73669d7711ca44aa9cac602a
# 57     45a523faa4defdf60118a90301b8a23e  26c4ac9998f72d4fcdca3c6e27089f1b
# 70     951a3591f5bcc0b0c558461c9bf49d8e  801524a8fbd37484e8d8c23448f113b5
# ...                                 ...                               ...
# 99197  51de4e06a6b701cb2be47ea0e689437b  b7467ae483dbe956fe9acdf0b1e6e3f4
# 99198  445a7bd5ce7f7bc9c28a5844c2466acc  2d687102eef8e4949a9d2af49e8fa946
# 99212  3ea12859f456855149b564d1a221f87a  f62f01ec64c6b221f926ba560907d8f7
# 99215  a709d176f59bc3af77f4149c96bae357  d5cb12269711bd1eaf7eed8fd32a7c95
# 99216  115d72425fc59eec9a2e9d7594c6d93d  acd45245723df7cb52772a34416b41b1
#
#        review_score       review_comment_title  \
# ...

# %%
df_bad_score = df_order_reviews[df_order_reviews['review_score'] < 3]
df_bad_score
# Out:
#                               review_id                          order_id  \
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 16     9314d6f9799f5bfba510cc7bcd468c01  0dacf04c5ad59fd5a0cc1faa07c34e39
# 19     373cbeecea8286a2b66c97b1b157ec46  583174fbe37d3d5f0d6661be3aad1786
# 29     2c5e27fc178bde7ac173c9c62c31b070  0ce9a24111d850192a933fcaab6fbad3
# 32     58044bca115705a48fe0e00a21390c54  68e55ca79d04a79f20d4bfc0146f4b66
# ...                                 ...                               ...
# 99174  cf0b8c06ba024a8a8d3f2ac51fcd99f4  fff2cdc825f9fc0ba3c04227cfa02303
# 99184  6cf47345d15e054dd6df872e929bdb27  54e6829fe81bc86cf88b12e6d07ea298
# 99200  2ee221b28e5b6fceffac59487ed39348  f2d12dd37eaef72ed7b1186b2edefbcd
# 99203  5085bc489aa6b58a29c4f922d59ff826  18ed848509774f56cc8c1c0a1903ad7f
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score     review_comment_title  \
# ...

# %% [markdown]
# Porcentaje de buenos scores, regulares y malos.
#
# Buenos: de 4 y 5
#
# Regulares: 3
#
# Malos: 1 y 2

# %%
perc_good_score = round(df_good_score['review_score'].count() / df_order_reviews['review_score'].count() * 100, 2)
perc_good_score
# Out:
# 77.07

# %%
perc_regular_score = round(df_regular_score['review_score'].count() / df_order_reviews['review_score'].count() * 100, 2)
perc_regular_score
# Out:
# 8.24

# %%
perc_bad_score = round(df_bad_score['review_score'].count() / df_order_reviews['review_score'].count() * 100, 2)
perc_bad_score
# Out:
# 14.69

# %% [markdown]
# # Queremos saber qué categorías son las más vendidas y las menos vendidas, para luego ver las más calificadas.
# Previamente se encontraron categorías con alto promedio de calificación pero con pocas unidades vendidas, lo que da un sesgo a la información que se busca.
#
# Vamos a escoger las categorías con mínimo 100 ventas para hacer esta evaluación

# %%
df_products_orderitems_merged = df_products.merge(df_order_items, on='product_id')[['product_category_name', 'product_id']]
df_count_sells = df_products.merge(df_order_items, on='product_id')[['product_category_name', 'product_id']].groupby('product_category_name').count().sort_values(by=['product_id'], ascending=False)
df_count_sells = df_count_sells[df_count_sells['product_id'] > 100]
df_count_sells.reset_index()
#df_products_orderitems_merged
# Out:
#                              product_category_name  product_id
# 0                                  cama_mesa_banho       11115
# 1                                     beleza_saude        9670
# 2                                    esporte_lazer        8641
# 3                                 moveis_decoracao        8334
# 4                           informatica_acessorios        7827
# 5                            utilidades_domesticas        6964
# 6                               relogios_presentes        5991
# 7                                        telefonia        4545
# 8                               ferramentas_jardim        4347
# 9                                       automotivo        4235
# 10                                      brinquedos        4117
# 11                                      cool_stuff        3796
# 12                                      perfumaria        3419
# 13                                           bebes        3065
# ...

# %% [markdown]
# **Categorías más vendidas**

# %%
df_most_sold = df_count_sells.head(20).reset_index()
df_most_sold
# Out:
#           product_category_name  product_id
# 0               cama_mesa_banho       11115
# 1                  beleza_saude        9670
# 2                 esporte_lazer        8641
# 3              moveis_decoracao        8334
# 4        informatica_acessorios        7827
# 5         utilidades_domesticas        6964
# 6            relogios_presentes        5991
# 7                     telefonia        4545
# 8            ferramentas_jardim        4347
# 9                    automotivo        4235
# 10                   brinquedos        4117
# 11                   cool_stuff        3796
# 12                   perfumaria        3419
# 13                        bebes        3065
# 14                  eletronicos        2767
# 15                    papelaria        2517
# 16  fashion_bolsas_e_acessorios        2031
# 17                     pet_shop        1947
# 18            moveis_escritorio        1691
# 19               consoles_games        1137

# %% [markdown]
# **Ahora veremos las menos vendidas:**

# %%
df_less_sold = df_count_sells.sort_values(by='product_id').head(20).reset_index()
df_less_sold
# Out:
#                              product_category_name  product_id
# 0               construcao_ferramentas_ferramentas         103
# 1                                    moveis_quarto         109
# 2                   fashion_underwear_e_moda_praia         131
# 3                          fashion_roupa_masculina         132
# 4                                 artigos_de_natal         153
# 5                 construcao_ferramentas_seguranca         194
# 6                          sinalizacao_e_seguranca         199
# 7                                              pcs         203
# 8                                            artes         209
# 9                        agro_industria_e_comercio         212
# 10                   construcao_ferramentas_jardim         238
# 11                              eletrodomesticos_2         238
# 12                                fashion_calcados         262
# 13                                  telefonia_fixa         264
# ...

# %% [markdown]
# Mezclaremos los dataframes implicados para el asunto: order_reviews con orders, luego con order_items y finalmente con productos.
#
# **Las 5 categorías mejor calificadas**

# %% [markdown]
# **Hasta ahora logré condensar las dos preguntas(score promedio y los más vendidos)** y este es el resultado:

# %%
df_score_by_category = df_order_reviews.merge(df_orders, on='order_id').merge(df_order_items, on='order_id').merge(df_products, on='product_id')[['product_category_name', 'review_score', 'product_id']]
df_score_by_category = df_score_by_category.groupby('product_category_name')[['review_score', 'product_id']].agg({'review_score': np.mean, 'product_id': lambda x: x.count()}).sort_values('product_id', ascending=False)
plt.plot(df_score_by_category[df_score_by_category['product_id'] > 100]['review_score'])
plt.title('Score Promedio')
plt.show()
plt.plot(df_score_by_category[df_score_by_category['product_id'] > 100]['product_id'], 'r')
plt.title('Unidades Vendidas')
plt.show()

# %% [markdown]
# Aunque no se aprecian los nombres de las categorías, se entiende claramente que ***tener muchas o pocas ventas no generan una relación directamente proporcional con la calificación promedio de esa categoría***. Sí se ve que se reduce la 'oscilación' del score promedio a partir de las 3000 unidades vendidas.

# %%
df_highest_scores = df_score_by_category.groupby('product_category_name')[['review_score']].apply(np.mean).sort_values('review_score', ascending=False).head(20).reset_index()
df_highest_scores
# Out:
#                  product_category_name  review_score
# 0                    cds_dvds_musicais      4.642857
# 1        fashion_roupa_infanto_juvenil      4.500000
# 2               livros_interesse_geral      4.446266
# 3   construcao_ferramentas_ferramentas      4.444444
# 4                               flores      4.419355
# 5                    livros_importados      4.400000
# 6                      livros_tecnicos      4.368421
# 7                    alimentos_bebidas      4.315412
# 8                     malas_acessorios      4.315257
# 9          portateis_casa_forno_e_cafe      4.302632
# 10                     fashion_esporte      4.258065
# 11                    fashion_calcados      4.233716
# 12                           alimentos      4.218182
# 13                              musica      4.210526
# 14                           cine_foto      4.205479
# 15                           papelaria      4.193857
# 16                            pet_shop      4.185147
# ...

# %%
df_lowest_scores = df_score_by_category.groupby('product_category_name')[['review_score']].apply(np.mean).sort_values('review_score').head(20).reset_index()
df_lowest_scores
# Out:
#                             product_category_name  review_score
# 0                              seguros_e_servicos      2.500000
# 1                                 fraldas_higiene      3.256410
# 2   portateis_cozinha_e_preparadores_de_alimentos      3.266667
# 3                                        pc_gamer      3.333333
# 4                               moveis_escritorio      3.493183
# 5                                 casa_conforto_2      3.629630
# 6                         fashion_roupa_masculina      3.641221
# 7                                  telefonia_fixa      3.683206
# 8                               artigos_de_festas      3.767442
# 9                          fashion_roupa_feminina      3.780000
# 10                      moveis_colchao_e_estofado      3.815789
# 11                                          audio      3.825485
# 12                                  casa_conforto      3.829885
# 13               construcao_ferramentas_seguranca      3.844560
# ...

# %% [markdown]
# Ahora vamos a unir los dataframes así: *Score más alto con mejores ventas, score más bajos con menores unidades vendidas de la categoría*...

# %%
df_most_sold.merge(df_highest_scores, on='product_category_name')
# Out:
#   product_category_name  product_id  review_score
# 0            perfumaria        3419      4.161941
# 1             papelaria        2517      4.193857
# 2              pet_shop        1947      4.185147

# %% [markdown]
# De los 20 productos de un dataframe y del otro dataframe, tienen en común 3 productos con buenas ventas y alto score
#
# Esto quiere decir lo siguiente: **No hay una correlación directa entre las unidades vendidas de categoría y el score promedio**
#
# Veamos con los más bajos...

# %%
df_less_sold.merge(df_lowest_scores, on='product_category_name')
# Out:
#               product_category_name  product_id  review_score
# 0           fashion_roupa_masculina         132      3.641221
# 1  construcao_ferramentas_seguranca         194      3.844560
# 2                             artes         209      3.937198
# 3                    telefonia_fixa         264      3.683206

# %% [markdown]
# Concluimos que *tener un bajo nivel de ventas no hace que el score sea bajo; tener un alto nivel de ventas, no significa que se tiene un alto score*. (Estos análisis se hicieron antes de las gráficas de arriba que comparan el score promedio y las unidades vendidas, de a poco voy elevando mi ki de análisis :D)
#
# Busquemos si depende de otros aspectos, tal vez pueda ser el cumplimiento o no en las fechas de entrega. Eso lo veremos más tarde.

# %% [markdown]
# # Sección sobre dinero y formas de pago...

# %% [markdown]
# **Ventas según la forma de pago**

# %% [markdown]
# *Y ahora, tenemos gráficamente que a mayores unidades vendidas, mayores ventas*

# %%
df_sells_vs_counts = df_order_payments.copy()
df_sells_vs_counts = df_sells_vs_counts.groupby('payment_type')[['payment_type', 'payment_value']].agg({'payment_type':lambda x: x.count(), 'payment_value': np.sum})#.reset_index()
#df_sells_vs_counts
plt.plot(df_sells_vs_counts['payment_type'])
plt.title('Tipo de Pago vs Unidades Vendidas')
plt.xlabel = 'Tipo de Pago'
plt.ylabel = 'Unidades Vendidas'
plt.show()
plt.plot(df_sells_vs_counts['payment_value'], 'r')
plt.title('Tipo de Pago vs Ventas')
plt.ylabel = 'Unidades Vendidas'
plt.show()

# %% [markdown]
# Claramente vemos la proporcionalidad, que por suposición era evidente(por sesgo) antes de abrir el dataset. Esto nos da una idea de la proporcionalidad similar que hay de productos costosos y económicos a través de todas las formas de pago.

# %% [markdown]
# # ¿Influirá el incumplimiento en fechas de entrega en el score promedio?
#
# Para esto se debe crear una columna que establezca un Sí o un No para el hecho de haber cumplido o no el tiempo de entrega. Se debe manejar el uso de fechas y operaciones de fechas en Pandas.

# %% [markdown]
# Revisamos los tipos de datos de todas las columnas de fecha, sea que vaya a trabajar con ellas ahora o no.

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# Convertimos a datetime esas columnas...

# %%
df_orders['order_estimated_delivery_date'] = pd.to_datetime(df_orders['order_estimated_delivery_date'])
df_orders['order_delivered_customer_date'] = pd.to_datetime(df_orders['order_delivered_customer_date'])
df_orders['order_purchase_timestamp'] = pd.to_datetime(df_orders['order_purchase_timestamp'])
df_orders['order_approved_at'] = pd.to_datetime(df_orders['order_approved_at'])
df_orders['order_delivered_carrier_date'] = pd.to_datetime(df_orders['order_delivered_carrier_date'])
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# Creamos la columna "delivered_on_time" que diga si se entregó a tiempo, **1 para Sí, 0 para No**

# %%
df_orders['delivered_on_time'] = df_orders['order_estimated_delivery_date'] - df_orders['order_delivered_customer_date']
df_orders['delivered_on_time'] = df_orders['delivered_on_time'].apply(lambda x: 1 if x.days >= 0 else 0)
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# Vamos a ver cuál es el porcentaje de entregas fallidas de la empresa:

# %%
round(df_orders[df_orders['delivered_on_time'] == 0]['delivered_on_time'].count() / df_orders['delivered_on_time'].count() * 100, 1)
# Out:
# 10.9

# %% [markdown]
# **De 100 envíos, 11 no se están entregando dentro de las fechas esperadas**.
#
# No es tan alto el porcentaje. A priori, pensamos que esto puede impactar negativamente en las calificaciones promedio de las categorías.

# %% [markdown]
# Ahora unimos los datasets involucrados para la consulta. Se me ocurre después separarlos según si se entrega a tiempo y si no.

# %%
df_score_by_category = df_order_reviews.merge(df_orders, on='order_id').merge(df_order_items, on='order_id').merge(df_products, on='product_id')[['product_category_name', 'review_score', 'product_id', 'delivered_on_time']]

df_delivered_on_time = df_score_by_category[df_score_by_category['delivered_on_time'] == 1][['product_category_name', 'review_score', 'product_id']]
df_delivered_off_time = df_score_by_category[df_score_by_category['delivered_on_time'] == 0][['product_category_name', 'review_score', 'product_id']]

df_delivered_on_time = df_delivered_on_time.groupby('product_category_name')[['review_score', 'product_id']].agg({'review_score': np.mean, 'product_id': lambda x: x.count()}).sort_values('product_id', ascending=False)
a = df_delivered_on_time[df_delivered_on_time['product_id'] > 100].sort_values(by=['review_score'], ascending = False).reset_index().sort_values(by=['product_category_name'])#.head(10)

df_delivered_off_time = df_delivered_off_time.groupby('product_category_name')[['review_score', 'product_id']].agg({'review_score': np.mean, 'product_id': lambda x: x.count()}).sort_values('product_id', ascending=False)
b = df_delivered_off_time[df_delivered_off_time['product_id'] > 100].sort_values(by=['review_score'], ascending = False).reset_index().sort_values(by=['product_category_name'])#.head(10)
## Hacemos un merge de tipo inner para que no se tengan en cuenta las categorías que no hayan en común. 
# Esto quiere decir que hay categorías que o siempre han sido entregadas a tiempo o que siempre han sido entregadas a destiempo. 
# La salida nos mostrará que de 48 categorías, 5 no están en a y b al tiempo.
c_merge = a.merge(b, on='product_category_name', how='inner')
c_merge
# Out:
#           product_category_name  review_score_x  product_id_x  review_score_y  \
# 0                    automotivo        4.250728          3777        2.461009
# 1                         bebes        4.243732          2712        2.139881
# 2                  beleza_saude        4.344472          8619        2.448343
# 3                    brinquedos        4.349300          3716        2.269333
# 4               cama_mesa_banho        4.048914         10079        2.435728
# 5                consoles_games        4.258258           999        2.187500
# 6                    cool_stuff        4.316247          3453        2.307210
# 7                   eletronicos        4.210462          2447        2.635762
# 8                 esporte_lazer        4.298465          7820        2.291463
# 9   fashion_bolsas_e_acessorios        4.308556          1870        2.331361
# 10           ferramentas_jardim        4.210567          3918        2.442822
# ...

# %% [markdown]
# Este hallazgo del Dataframe es interesante: **El promedio del score de una categoría, en general suele bajar si el producto es entregado fuera de tiempo**
#
# Veamos esto de una manera gráfica:

# %%
fig, axes = plt.subplots(figsize=(20,6))
axes.plot(c_merge['product_category_name'], c_merge['review_score_x'], 'r')
axes.plot(c_merge['product_category_name'], c_merge['review_score_y'], 'b')
plt.show()

# %%
df_score_by_category = df_order_reviews.merge(df_orders, on='order_id').merge(df_order_items, on='order_id').merge(df_products, on='product_id')[['product_category_name', 'review_score', 'product_id', 'delivered_on_time']].groupby(['product_category_name', 'delivered_on_time'])[['review_score', 'product_id']].agg({'review_score': np.mean, 'product_id': lambda x: x.count()}).sort_values(by=['product_category_name'])
df_score_by_category = df_score_by_category.reset_index()
df_score_by_category = df_score_by_category[df_score_by_category['product_id'] >= 100]

plt.figure(figsize=(20,20))
sns.displot(data=df_score_by_category, x='product_category_name', y='review_score', hue='delivered_on_time', kind='hist')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.barplot(data=df_score_by_category, x='product_category_name', y='review_score', hue='delivered_on_time')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# Estamos probando que **cuando se entrega un producto fuera de tiempo, el usuario sin duda le da calificaciones bajas al producto.**

# %% [markdown]
# # Comportamiento porcentaje de entregas fallidas a través del tiempo

# %% [markdown]
# Agrupar mensualmente el comportamiento del porcentaje de entregas fallidas y graficar.

# %%
df_monthly_prctg_delivered_off_time = df_orders[df_orders['delivered_on_time'] == 0][['order_estimated_delivery_date', 'delivered_on_time']].groupby('order_estimated_delivery_date')[['delivered_on_time']].count().resample('M').sum().cumsum().reset_index()
df_monthly_prctg_delivered_off_time.head()
# Out:
#   order_estimated_delivery_date  delivered_on_time
# 0                    2016-09-30                  1
# 1                    2016-10-31                  6
# 2                    2016-11-30                 33
# 3                    2016-12-31                 61
# 4                    2017-01-31                 61

# %%
df_monthly_prctg_delivered = df_orders[['order_estimated_delivery_date', 'delivered_on_time']].groupby('order_estimated_delivery_date')[['delivered_on_time']].count().resample('M').sum().cumsum().reset_index()
df_monthly_prctg_delivered.head()
# Out:
#   order_estimated_delivery_date  delivered_on_time
# 0                    2016-09-30                  1
# 1                    2016-10-31                  7
# 2                    2016-11-30                178
# 3                    2016-12-31                326
# 4                    2017-01-31                329

# %%
a = df_monthly_prctg_delivered_off_time.merge(df_monthly_prctg_delivered, on='order_estimated_delivery_date', how='inner')
a['delivered_off_time_percentage'] = round(a['delivered_on_time_x'] / a['delivered_on_time_y'] * 100, 1)

# %%
plt.figure(figsize=(20,6))
sns.barplot(data=a, x=a['order_estimated_delivery_date'], y='delivered_off_time_percentage')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# **El porcentaje mensual acumulado se va estabilizando hacia el 10.9%**

# %%
a
# Out:
#    order_estimated_delivery_date  delivered_on_time_x  delivered_on_time_y  \
# 0                     2016-09-30                    1                    1
# 1                     2016-10-31                    6                    7
# 2                     2016-11-30                   33                  178
# 3                     2016-12-31                   61                  326
# 4                     2017-01-31                   61                  329
# 5                     2017-02-28                   85                  645
# 6                     2017-03-31                  367                 3446
# 7                     2017-04-30                  584                 5681
# 8                     2017-05-31                  947                 8718
# 9                     2017-06-30                 1199                12357
# 10                    2017-07-31                 1449                15688
# ...

# %% [markdown]
# # Ventas por mes

# %% [markdown]
# Necesitamos unir 2 datasets, uno que contiene el valor de la compra y otro que tiene la fecha.

# %%
ventas_por_mes = df_orders.merge(df_order_payments, on='order_id', how='inner')

# %%
ventas_por_mes['fecha_mes_anio'] = ventas_por_mes['order_purchase_timestamp'].dt.strftime(date_format="%Y-%m")
ventas_por_mes['fecha_mes_anio'] = pd.to_datetime(ventas_por_mes['fecha_mes_anio'])
ventas_por_mes = ventas_por_mes[['fecha_mes_anio', 'payment_value']]
ventas_por_mes = ventas_por_mes.groupby('fecha_mes_anio')[['payment_value']].sum().resample('M').sum().reset_index()
#ventas_por_mes['num_mes'] = ventas_por_mes['fecha_mes_anio'].
ventas_por_mes.head()
# Out:
#   fecha_mes_anio  payment_value
# 0     2016-09-30         252.24
# 1     2016-10-31       59090.48
# 2     2016-11-30           0.00
# 3     2016-12-31          19.62
# 4     2017-01-31      138488.04

# %% [markdown]
# Elimino datos de los 2 meses finales porque introducen mucho ruido y bajan el score del modelo.

# %%
ventas_por_mes.drop(range(24, 26), axis=0, inplace=True)

# %%
ventas_por_mes.tail()
# Out:
#    fecha_mes_anio  payment_value
# 19     2018-04-30     1160785.48
# 20     2018-05-31     1153982.15
# 21     2018-06-30     1023880.50
# 22     2018-07-31     1066540.75
# 23     2018-08-31     1022425.32

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(data = ventas_por_mes, x='fecha_mes_anio', y='payment_value')
plt.show()

# %% [markdown]
# Ahora vamos a emplear una regresión lineal

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
reg = LinearRegression()
# Se obtienen los arreglos para X e y
X = ventas_por_mes['fecha_mes_anio'].values.reshape(-1, 1)
y = ventas_por_mes['payment_value']

# Se estandarizan las variables
sc_x = StandardScaler()
sc_y = StandardScaler()
X = sc_x.fit_transform(X)
y = sc_y.fit_transform(y[:, np.newaxis]).flatten()

# Separamos el dataset en conjunto de preparación y conjunto de prueba
X_input, X_test, y_input, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Ajustamos el modelo con los datos de entrenamiento
model = reg.fit(X_input, y_input)
print('Intercepto: {:.3f}'.format(reg.intercept_))
print('Coeficientes:', reg.coef_)

# Calculamos la exactitud del modelo
print('Exactitud: {:.3f}'.format(reg.score(X_test, y_test)))

#predecimos con el 20%
y_grafica = model.predict(X_test)

# Guardamos a, y b para graficar con los puntos
a = round(reg.coef_[0], 3)
b = round(reg.intercept_, 3)
print(a,b)
# Out:
# Intercepto: -0.049
# Coeficientes: [0.85160929]
# Exactitud: 0.812
# 0.852 -0.049
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# Tenemos un bueno modelo con un R-cuadrado de valor aceptable.

# %%
plt.plot(X_test, y_grafica, label='Regresión Lineal', color='blue')
plt.scatter(X_test, y_test, label='Datos de prueba', color='green')
plt.scatter(X_input, y_input, label='Training Data', color='red')
plt.show()

# %% [markdown]
# **¿De qué estados salen las entregas fuera de tiempo?**

# %%
df_customers_orders = df_customers.merge(df_orders[df_orders['delivered_on_time'] == 0], on='customer_id', how='inner')[['customer_state', 'delivered_on_time']]
a = df_customers_orders.groupby('customer_state').count().reset_index().sort_values(by = 'delivered_on_time', ascending=False)

plt.figure(figsize=(16,10))
sns.barplot(data= a, x='customer_state', y='delivered_on_time')
plt.show()

# %% [markdown]
# **¿Tendrá relación con los estados donde más órdenes de compra se solicitan?**

# %%
b = df_customers.merge(df_orders, on='customer_id', how='inner')[['customer_state', 'delivered_on_time']].groupby('customer_state').count().reset_index().sort_values(by = 'delivered_on_time', ascending=False)
plt.figure(figsize=(16,10))
sns.barplot(data= b, x='customer_state', y='delivered_on_time')
plt.show()

# %% [markdown]
# Tiene cierta relación vender mucho en un estado y tener altos índices de fallas en entregas. No parece tener que ver con las regiones más olvidadas.
